# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder,StandardScaler

# %%
data = pd.read_excel('/Users/haitonghuang/Downloads/Date_Fruit_Datasets/Date_Fruit_Datasets.xlsx')
data.head(20)
# Out:
#       AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0   422163  2378.9080    837.8484    645.6693        0.6373  733.1539
# 1   338136  2085.1440    723.8198    595.2073        0.5690  656.1464
# 2   526843  2647.3940    940.7379    715.3638        0.6494  819.0222
# 3   416063  2351.2100    827.9804    645.2988        0.6266  727.8378
# 4   347562  2160.3540    763.9877    582.8359        0.6465  665.2291
# 5   408953  2326.6931    840.1821    622.0076        0.6722  721.5921
# 6   451414  2457.2080    889.3253    652.4316        0.6796  758.1281
# 7   382636  2275.7791    808.0833    609.2819        0.6569  697.9880
# 8   546063  2714.9480    916.3737    766.4536        0.5481  833.8279
# 9   420044  2391.1230    836.9280    645.1822        0.6370  731.3116
# 10  364495  2216.4900    790.9014    590.7698        0.6649  681.2411
# 11  404243  2345.5349    823.7634    628.8527        0.6459  717.4247
# ...

# %%
data.describe()
# Out:
#                 AREA    PERIMETER   MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY  \
# count     898.000000   898.000000   898.000000  898.000000    898.000000
# mean   298295.207127  2057.660953   750.811994  495.872785      0.737468
# std    107245.205337   410.012459   144.059326  114.268917      0.088727
# min      1987.000000   911.828000   336.722700    2.283200      0.344800
# 25%    206948.000000  1726.091500   641.068650  404.684375      0.685625
# 50%    319833.000000  2196.345450   791.363400  495.054850      0.754700
# 75%    382573.000000  2389.716575   858.633750  589.031700      0.802150
# max    546063.000000  2811.997100  1222.723000  766.453600      1.000000
#
#           EQDIASQ    SOLIDITY    CONVEX_AREA      EXTENT  ASPECT_RATIO  ...  \
# count  898.000000  898.000000     898.000000  898.000000    898.000000  ...
# mean   604.577938    0.981840  303845.592428    0.736267      2.131102  ...
# std    119.593888    0.018157  108815.656947    0.053745     17.820778  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 898 entries, 0 to 897
# Data columns (total 35 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   AREA           898 non-null    int64
#  1   PERIMETER      898 non-null    float64
#  2   MAJOR_AXIS     898 non-null    float64
#  3   MINOR_AXIS     898 non-null    float64
#  4   ECCENTRICITY   898 non-null    float64
#  5   EQDIASQ        898 non-null    float64
#  6   SOLIDITY       898 non-null    float64
#  7   CONVEX_AREA    898 non-null    int64
#  8   EXTENT         898 non-null    float64
#  9   ASPECT_RATIO   898 non-null    float64
#  10  ROUNDNESS      898 non-null    float64
#  11  COMPACTNESS    898 non-null    float64
#  12  SHAPEFACTOR_1  898 non-null    float64
#  13  SHAPEFACTOR_2  898 non-null    float64
#  14  SHAPEFACTOR_3  898 non-null    float64
#  15  SHAPEFACTOR_4  898 non-null    float64
#  16  MeanRR         898 non-null    float64
# ...

# %%
data.Class.value_counts()
# Out:
# 2    204
# 5    199
# 4    166
# 1     98
# 6     94
# 3     72
# 0     65
# Name: Class, dtype: int64

# %%
x = data.drop('Class',axis=1).to_numpy()
y = data['Class'].to_numpy()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train, y_test = train_test_split(x, y, stratify=y,test_size=0.2,random_state=100)

# %% [markdown]
# This stratify parameter makes a split so that the proportion of values in the sample produced will be the same as the proportion of values provided to parameter stratify.
#
# For example, if variable y is a binary categorical variable with values 0 and 1 and there are 25% of zeros and 75% of ones, stratify=y will make sure that your random split has 25% of 0's and 75% of 1's.

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train2 = sc.fit_transform(x_train)
x_test2 = sc.transform(x_test)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix

for name,method in [('DT', DecisionTreeClassifier(random_state=100))]: 
    method.fit(x_train2,y_train)
    predict = method.predict(x_test2)
    target_names=['DOKOL','SAFAVI','ROTANA','DEGLET','SOGAY','IRAQI','BERHI']
    print('\nEstimator: {}'.format(name)) 
    print(confusion_matrix(y_test,predict))  
    print(classification_report(y_test,predict,target_names=target_names))
# Out:
# Estimator: DT
# [[ 9  0  0  4  0  0  0]
#  [ 0 12  6  0  0  0  2]
#  [ 0  3 37  1  0  0  0]
#  [ 5  0  0  7  1  1  0]
#  [ 0  2  0  0 30  0  1]
#  [ 0  0  0  0  0 39  1]
#  [ 0  3  0  0  0  1 15]]
#               precision    recall  f1-score   support
#
#        DOKOL       0.64      0.69      0.67        13
#       SAFAVI       0.60      0.60      0.60        20
#       ROTANA       0.86      0.90      0.88        41
#       DEGLET       0.58      0.50      0.54        14
#        SOGAY       0.97      0.91      0.94        33
#        IRAQI       0.95      0.97      0.96        40
#        BERHI       0.79      0.79      0.79        19
#
#     accuracy                           0.83       180
#    macro avg       0.77      0.77      0.77       180
# weighted avg       0.83      0.83      0.83       180

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix  

for name,method in [('SVM', SVC(kernel='linear',random_state=100))]: 
    method.fit(x_train2,y_train)
    predict = method.predict(x_test2)
    target_names=['DOKOL','SAFAVI','ROTANA','DEGLET','SOGAY','IRAQI','BERHI']
    print('\nEstimator: {}'.format(name)) 
    print(confusion_matrix(y_test,predict))  
    print(classification_report(y_test,predict,target_names=target_names))
# Out:
# Estimator: SVM
# [[11  0  0  1  1  0  0]
#  [ 0 14  5  0  0  0  1]
#  [ 0  0 41  0  0  0  0]
#  [ 2  0  0 12  0  0  0]
#  [ 0  1  0  0 31  0  1]
#  [ 0  0  0  0  0 40  0]
#  [ 0  2  0  0  1  0 16]]
#               precision    recall  f1-score   support
#
#        DOKOL       0.85      0.85      0.85        13
#       SAFAVI       0.82      0.70      0.76        20
#       ROTANA       0.89      1.00      0.94        41
#       DEGLET       0.92      0.86      0.89        14
#        SOGAY       0.94      0.94      0.94        33
#        IRAQI       1.00      1.00      1.00        40
#        BERHI       0.89      0.84      0.86        19
#
#     accuracy                           0.92       180
#    macro avg       0.90      0.88      0.89       180
# weighted avg       0.92      0.92      0.91       180

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np

# %%
data_1 = pd.read_csv('/Users/haitonghuang/Downloads/archive (1)/features.csv')
data_1
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2010-02-05        42.31       2.572        NaN        NaN
# 1         1  2010-02-12        38.51       2.548        NaN        NaN
# 2         1  2010-02-19        39.93       2.514        NaN        NaN
# 3         1  2010-02-26        46.63       2.561        NaN        NaN
# 4         1  2010-03-05        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
data_2 = pd.read_csv('/Users/haitonghuang/Downloads/archive (1)/stores.csv')
data_2
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# 5       6    A  202505
# 6       7    B   70713
# 7       8    A  155078
# 8       9    B  125833
# 9      10    B  126512
# 10     11    A  207499
# 11     12    B  112238
# 12     13    A  219622
# 13     14    A  200898
# 14     15    B  123737
# 15     16    B   57197
# 16     17    B   93188
# 17     18    B  120653
# 18     19    A  203819
# 19     20    A  203742
# 20     21    B  140167
# 21     22    B  119557
# 22     23    B  114533
# 23     24    A  203819
# 24     25    B  128107
# 25     26    A  152513
# 26     27    A  204184
# 27     28    A  206302
# 28     29    B   93638
# 29     30    C   42988
# 30     31    A  203750
# 31     32    A  203007
# 32     33    A   39690
# 33     34    A  158114
# 34     35    B  103681
# 35     36    A   39910
# 36     37    C   39910
# 37     38    C   39690
# 38     39    A  184109
# ...

# %%
data_3 = pd.read_csv('/Users/haitonghuang/Downloads/archive (1)/train.csv')
data_3
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  2010-02-05      24924.50      False
# 1           1     1  2010-02-12      46039.49       True
# 2           1     1  2010-02-19      41595.55      False
# 3           1     1  2010-02-26      19403.54      False
# 4           1     1  2010-03-05      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  2012-09-28        508.37      False
# 421566     45    98  2012-10-05        628.10      False
# 421567     45    98  2012-10-12       1061.02      False
# 421568     45    98  2012-10-19        760.01      False
# 421569     45    98  2012-10-26       1076.80      False
#
# [421570 rows x 5 columns]

# %%
#set option to show all columns
pd.set_option("display.max.columns", None)

# %%
full_file = pd.merge(data_1,data_3, on = 'Store')
print(full_file)
# Out:
#           Store      Date_x  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0             1  2010-02-05        42.31       2.572        NaN        NaN
# 1             1  2010-02-05        42.31       2.572        NaN        NaN
# 2             1  2010-02-05        42.31       2.572        NaN        NaN
# 3             1  2010-02-05        42.31       2.572        NaN        NaN
# 4             1  2010-02-05        42.31       2.572        NaN        NaN
# ...         ...         ...          ...         ...        ...        ...
# 76725735     45  2013-07-26        76.06       3.804     212.02     851.73
# 76725736     45  2013-07-26        76.06       3.804     212.02     851.73
# 76725737     45  2013-07-26        76.06       3.804     212.02     851.73
# 76725738     45  2013-07-26        76.06       3.804     212.02     851.73
# 76725739     45  2013-07-26        76.06       3.804     212.02     851.73
#
# ...

# %%
df = full_file[['Temperature','Fuel_Price','Dept','MarkDown1','MarkDown2','MarkDown3','MarkDown4','MarkDown5','Weekly_Sales','IsHoliday_y','IsHoliday_x','CPI','Dept','Unemployment','Store']]

df
# Out:
#           Temperature  Fuel_Price  Dept  MarkDown1  MarkDown2  MarkDown3  \
# 0               42.31       2.572     1        NaN        NaN        NaN
# 1               42.31       2.572     1        NaN        NaN        NaN
# 2               42.31       2.572     1        NaN        NaN        NaN
# 3               42.31       2.572     1        NaN        NaN        NaN
# 4               42.31       2.572     1        NaN        NaN        NaN
# ...               ...         ...   ...        ...        ...        ...
# 76725735        76.06       3.804    98     212.02     851.73       2.06
# 76725736        76.06       3.804    98     212.02     851.73       2.06
# 76725737        76.06       3.804    98     212.02     851.73       2.06
# 76725738        76.06       3.804    98     212.02     851.73       2.06
# 76725739        76.06       3.804    98     212.02     851.73       2.06
#
#           MarkDown4  MarkDown5  Weekly_Sales  IsHoliday_y  IsHoliday_x  \
# ...

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Temperature     0
# Fuel_Price      0
# Dept            0
# MarkDown1       0
# MarkDown2       0
# MarkDown3       0
# MarkDown4       0
# MarkDown5       0
# Weekly_Sales    0
# IsHoliday_y     0
# IsHoliday_x     0
# CPI             0
# Dept            0
# Unemployment    0
# Store           0
# dtype: int64

# %%
df["IsHoliday_y"] = df["IsHoliday_y"].astype(int)
df['IsHoliday_x'] = df['IsHoliday_x'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20448422 entries, 942448 to 76590821
# Data columns (total 15 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Temperature   float64
#  1   Fuel_Price    float64
#  2   Dept          int64
#  3   MarkDown1     float64
#  4   MarkDown2     float64
#  5   MarkDown3     float64
#  6   MarkDown4     float64
#  7   MarkDown5     float64
#  8   Weekly_Sales  float64
#  9   IsHoliday_y   int64
#  10  IsHoliday_x   int64
#  11  CPI           float64
#  12  Dept          int64
#  13  Unemployment  float64
#  14  Store         int64
# dtypes: float64(10), int64(5)
# memory usage: 2.4 GB

# %%
df.shape
# Out:
# (20448422, 15)

# %%
df
# Out:
#           Temperature  Fuel_Price  Dept  MarkDown1  MarkDown2  MarkDown3  \
# 942448          59.11       3.297     1   10382.90    6115.67     215.07
# 942449          59.11       3.297     1   10382.90    6115.67     215.07
# 942450          59.11       3.297     1   10382.90    6115.67     215.07
# 942451          59.11       3.297     1   10382.90    6115.67     215.07
# 942452          59.11       3.297     1   10382.90    6115.67     215.07
# ...               ...         ...   ...        ...        ...        ...
# 76590817        56.27       3.676    98    1399.81      39.89      44.38
# 76590818        56.27       3.676    98    1399.81      39.89      44.38
# 76590819        56.27       3.676    98    1399.81      39.89      44.38
# 76590820        56.27       3.676    98    1399.81      39.89      44.38
# 76590821        56.27       3.676    98    1399.81      39.89      44.38
#
#           MarkDown4  MarkDown5  Weekly_Sales  IsHoliday_y  IsHoliday_x  \
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression 
from sklearn import metrics
from sklearn import tree
from sklearn.preprocessing import StandardScaler,LabelEncoder

# %%
le = LabelEncoder()
ss = StandardScaler()

x = lb.fit_transform(df['IsHoliday_y'])
y = lb.fit_transform(df['[IsHoliday_x'])
# Out:
# /Users/haitonghuang/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3361: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return self._engine.get_loc(casted_key)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/vm/t0kfdtyd4j976j7k67x7nvpw0000gn/T/ipykernel_34354/2114990242.py in <module>
#       3
#       4
# ----> 5 cols = df['IsHoliday_y','IsHoliday_x']
#       6 df[cols] = le.fit_transform(df[cols])
#       7 df
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
# ...

# %%
feature_clos = ['Temperature','Fuel_Price','Dept','MarkDown1','MarkDown2','MarkDown3','MarkDown4','MarkDown5','Weekly_Sales','CPI','Unemployment']
x = df[feature_clos]
y = df['Store']
# Out:
# 942448       1
# 942449       1
# 942450       1
# 942451       1
# 942452       1
#             ..
# 76590817    45
# 76590818    45
# 76590819    45
# 76590820    45
# 76590821    45
# Name: Store, Length: 20448422, dtype: int64

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size = 0.3, random_state = 2)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(X_train)
x_test = sc.transform(X_test)

# %%
from sklearn.tree import DecisionTreeRegressor

Dtclf = DecisionTreeClassifier(max_depth = 5, random_state = 2)

Dtclf.fit(x_train,x_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/vm/t0kfdtyd4j976j7k67x7nvpw0000gn/T/ipykernel_9337/3989034080.py in <module>
#       3 Dtclf = DecisionTreeClassifier(max_depth = 5, random_state = 2)
#       4
# ----> 5 Dtclf.fit(x_train,x_train)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     901         """
#     902
# --> 903         super().fit(
#     904             X, y,
#     905             sample_weight=sample_weight,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     189
#     190         if is_classification:
# --> 191             check_classification_targets(y)
#     192             y = np.copy(y)
#     193
#
# ...

# %%
# Out:
# <AxesSubplot:>

# %%
y_predict = Dtclf.predict(X_test)

# %%
tree.plot_tree(Dtclf)
# Out:
# [Text(92.98360595223477, 213.25846153846155, 'X[9] <= 139.767\ngini = 0.973\nsamples = 14313895\nvalue = [422630, 437625, 278560, 416844, 252076, 429269, 355627\n380313, 235478, 368314, 415117, 359593, 447347, 421274\n367145, 283916, 324845, 414027, 419631, 464958, 362187\n352412, 387227, 437499, 370880, 379037, 458243, 410861\n337511, 35298, 411839, 450039, 9065, 394264, 306400\n4314, 20095, 51562, 400870, 357575, 430561, 29168, 28304\n10069, 384026]'),
#  Text(28.9398094302554, 204.89538461538461, 'X[10] <= 5.178\ngini = 0.935\nsamples = 5921584\nvalue = [0, 0, 0, 416844, 0, 0, 0, 0, 0, 368314, 0\n359593, 447347, 0, 367145, 0, 324845, 414027, 419631\n0, 0, 0, 387227, 437499, 0, 379037, 0, 410861\n337511, 0, 0, 0, 9065, 394264, 0, 0, 0, 51562, 0\n357575, 0, 29168, 0, 10069, 0]'),
# ...

# %%
from sklearn import metrics
r_square = metrics.accuracy_score(Y_test, y_predict)
print('Accuracy:',r_square)
# Out:
# Accuracy: 0.5132403851185267

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, y_predict))
print('Mean Squared Error:', metrics.mean_squared_error(Y_test, y_predict))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, y_predict)))
# Out:
# Mean Absolute Error: 0.0
# Mean Squared Error: 0.0
# Root Mean Squared Error: 0.0

# %%
DtReg.predict([[5,70,4.1,60]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/vm/t0kfdtyd4j976j7k67x7nvpw0000gn/T/ipykernel_9337/2414683188.py in <module>
# ----> 1 DtReg.predict([[5,70,4.1,60]])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py in predict(self, X, check_input)
#     440         """
#     441         check_is_fitted(self)
# --> 442         X = self._validate_X_predict(X, check_input)
#     443         proba = self.tree_.predict(X)
#     444         n_samples = X.shape[0]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py in _validate_X_predict(self, X, check_input)
#     405         """Validate the training data on predict (probabilities)."""
#     406         if check_input:
# --> 407             X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr",
#     408                                     reset=False)
# ...
